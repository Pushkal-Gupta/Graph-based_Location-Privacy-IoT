# %%
import pandas as pd
import numpy as np

# %%
import json

with open("../preprocessed data/city_graph.json", "r") as f:
    df_city = json.load(f)

# %%
device = pd.read_csv("../preprocessed data/device_locations.csv")

# %%
device.head()
# Out:
#    user_id  location_id            timestamp
# 0        0          551  2008-10-23 02:53:04
# 1        0          551  2008-10-23 02:53:10
# 2        0          551  2008-10-23 02:53:15
# 3        0          551  2008-10-23 02:53:20
# 4        0          551  2008-10-23 02:53:25

# %%
device["timestamp"].nunique()
# Out:
# 13246478

# %%
device["user_id"].nunique()
# Out:
# 179

# %%
device["location_id"].nunique()
# Out:
# 883

# %%
len(df_city["nodes"])
# Out:
# 900

# %%
node_ids = [n["id"] for n in df_city["nodes"]]
len(set(node_ids))
# Out:
# 900

# %%
x_vals = [n["x"] for n in df_city["nodes"]]
y_vals = [n["y"] for n in df_city["nodes"]]

len(set(x_vals))
len(set(y_vals))
# Out:
# 30

# %%
df_nodes = pd.DataFrame(df_city["nodes"])
df_nodes.head()
# Out:
#   id        x       y
# 0  0  116.205  39.805
# 1  1  116.215  39.805
# 2  2  116.225  39.805
# 3  3  116.235  39.805
# 4  4  116.245  39.805

# %%
device_locations = set(device["location_id"].astype(str))
city_node_ids = set(df_nodes["id"].astype(str))

# %%
missing_in_city = device_locations - city_node_ids
len(missing_in_city)
# Out:
# 0

# %%
unused_city_nodes = city_node_ids - device_locations
len(unused_city_nodes)
# Out:
# 17
